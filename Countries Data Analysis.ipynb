# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
df=pd.read_csv('Countries Table.csv')
df
# Out:
#               country  rank        area  landAreaKm cca2 cca3  netChange  \
# 0               India     1  3287590.00  2973190.00   IN  IND     0.4184
# 1               China     2  9706961.00  9424702.90   CN  CHN    -0.0113
# 2       United States     3  9372610.00  9147420.00   US  USA     0.0581
# 3           Indonesia     4  1904569.00  1877519.00   ID  IDN     0.0727
# 4            Pakistan     5   881912.00   770880.00   PK  PAK     0.1495
# ..                ...   ...         ...         ...  ...  ...        ...
# 229        Montserrat   230      102.00      102.00   MS  MSR        NaN
# 230  Falkland Islands   231    12173.00    12173.00   FK  FLK        NaN
# 231              Niue   232      261.00      261.00   NU  NIU     0.0000
# 232           Tokelau   233       12.00       10.00   TK  TKL        NaN
# 233      Vatican City   234        0.44        0.44   VA  VAT        NaN
#
#      growthRate  worldPercentage    density  densityMi  place    pop1980  \
# ...

# %%
df.drop_duplicates()
# Out:
#               country  rank        area  landAreaKm cca2 cca3  netChange  \
# 0               India     1  3287590.00  2973190.00   IN  IND     0.4184
# 1               China     2  9706961.00  9424702.90   CN  CHN    -0.0113
# 2       United States     3  9372610.00  9147420.00   US  USA     0.0581
# 3           Indonesia     4  1904569.00  1877519.00   ID  IDN     0.0727
# 4            Pakistan     5   881912.00   770880.00   PK  PAK     0.1495
# ..                ...   ...         ...         ...  ...  ...        ...
# 229        Montserrat   230      102.00      102.00   MS  MSR        NaN
# 230  Falkland Islands   231    12173.00    12173.00   FK  FLK        NaN
# 231              Niue   232      261.00      261.00   NU  NIU     0.0000
# 232           Tokelau   233       12.00       10.00   TK  TKL        NaN
# 233      Vatican City   234        0.44        0.44   VA  VAT        NaN
#
#      growthRate  worldPercentage    density  densityMi  place    pop1980  \
# ...

# %%
df.dropna(inplace=True)

# %%
df.columns
# Out:
# Index(['country', 'rank', 'area', 'landAreaKm', 'cca2', 'cca3', 'netChange',
#        'growthRate', 'worldPercentage', 'density', 'densityMi', 'place',
#        'pop1980', 'pop2000', 'pop2010', 'pop2022', 'pop2023', 'pop2030',
#        'pop2050'],
#       dtype='object')

# %%
pd.isnull(df)
# Out:
#      country   rank   area  landAreaKm   cca2   cca3  netChange  growthRate  \
# 0      False  False  False       False  False  False      False       False
# 1      False  False  False       False  False  False      False       False
# 2      False  False  False       False  False  False      False       False
# 3      False  False  False       False  False  False      False       False
# 4      False  False  False       False  False  False      False       False
# ..       ...    ...    ...         ...    ...    ...        ...         ...
# 222    False  False  False       False  False  False      False       False
# 223    False  False  False       False  False  False      False       False
# 224    False  False  False       False  False  False      False       False
# 225    False  False  False       False  False  False      False       False
# 226    False  False  False       False  False  False      False       False
#
# ...

# %%
pd.isnull(df).sum()
# Out:
# country            0
# rank               0
# area               0
# landAreaKm         0
# cca2               0
# cca3               0
# netChange          0
# growthRate         0
# worldPercentage    0
# density            0
# densityMi          0
# place              0
# pop1980            0
# pop2000            0
# pop2010            0
# pop2022            0
# pop2023            0
# pop2030            0
# pop2050            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 224 entries, 0 to 226
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          224 non-null    object
#  1   rank             224 non-null    int64
#  2   area             224 non-null    float64
#  3   landAreaKm       224 non-null    float64
#  4   cca2             224 non-null    object
#  5   cca3             224 non-null    object
#  6   netChange        224 non-null    float64
#  7   growthRate       224 non-null    float64
#  8   worldPercentage  224 non-null    float64
#  9   density          224 non-null    float64
#  10  densityMi        224 non-null    float64
#  11  place            224 non-null    int64
#  12  pop1980          224 non-null    int64
#  13  pop2000          224 non-null    int64
#  14  pop2010          224 non-null    int64
#  15  pop2022          224 non-null    int64
#  16  pop2023          224 non-null    int64
# ...

# %%
df.head()
# Out:
#          country  rank       area  landAreaKm cca2 cca3  netChange  \
# 0          India     1  3287590.0   2973190.0   IN  IND     0.4184
# 1          China     2  9706961.0   9424702.9   CN  CHN    -0.0113
# 2  United States     3  9372610.0   9147420.0   US  USA     0.0581
# 3      Indonesia     4  1904569.0   1877519.0   ID  IDN     0.0727
# 4       Pakistan     5   881912.0    770880.0   PK  PAK     0.1495
#
#    growthRate  worldPercentage   density  densityMi  place    pop1980  \
# 0      0.0081           0.1785  480.5033  1244.5036    356  696828385
# 1     -0.0002           0.1781  151.2696   391.7884    156  982372466
# 2      0.0050           0.0425   37.1686    96.2666    840  223140018
# 3      0.0074           0.0347  147.8196   382.8528    360  148177096
# 4      0.0198           0.0300  311.9625   807.9829    586   80624057
#
#       pop2000     pop2010     pop2022     pop2023     pop2030     pop2050
# ...

# %%
df.describe()
# Out:
#              rank          area    landAreaKm   netChange  growthRate  \
# count  224.000000  2.240000e+02  2.240000e+02  224.000000  224.000000
# mean   112.915179  6.036623e+05  5.782484e+05    0.010393    0.009980
# std     65.304852  1.796925e+06  1.723615e+06    0.034917    0.012489
# min      1.000000  2.020000e+00  2.000000e+00   -0.028600   -0.074500
# 25%     56.750000  6.106250e+03  5.832500e+03    0.000000    0.002575
# 50%    112.500000  8.748050e+04  8.549700e+04    0.000900    0.008350
# 75%    169.250000  4.467625e+05  4.163695e+05    0.008075    0.017775
# max    227.000000  1.709824e+07  1.637687e+07    0.418400    0.049800
#
#        worldPercentage       density     densityMi       place       pop1980  \
# count       224.000000    224.000000    224.000000  224.000000  2.240000e+02
# mean          0.004485    460.344308   1192.291751  434.093750  1.982751e+07
# std           0.017521   2021.319878   5235.218484  255.709819  8.349886e+07
# ...

# %%
df[['area']]=df[['area']].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 224 entries, 0 to 226
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          224 non-null    object
#  1   rank             224 non-null    int64
#  2   area             224 non-null    int32
#  3   landAreaKm       224 non-null    float64
#  4   cca2             224 non-null    object
#  5   cca3             224 non-null    object
#  6   netChange        224 non-null    float64
#  7   growthRate       224 non-null    float64
#  8   worldPercentage  224 non-null    float64
#  9   density          224 non-null    float64
#  10  densityMi        224 non-null    float64
#  11  place            224 non-null    int64
#  12  pop1980          224 non-null    int64
#  13  pop2000          224 non-null    int64
#  14  pop2010          224 non-null    int64
#  15  pop2022          224 non-null    int64
#  16  pop2023          224 non-null    int64
# ...

# %%
df[['landAreaKm']].describe()
# Out:
#          landAreaKm
# count  2.240000e+02
# mean   5.782484e+05
# std    1.723615e+06
# min    2.000000e+00
# 25%    5.832500e+03
# 50%    8.549700e+04
# 75%    4.163695e+05
# max    1.637687e+07

# %% [markdown]
# # Exploratory Data Analysis

# %%
Area=df.nlargest(10,"area")
ax=plt.subplots(figsize=(13,5))
plt.title("Largest Area ")
ax=sns.barplot(x="country",y="area",data=Area)
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
Rank=df.nsmallest(10,"rank")
ax=plt.subplots(figsize=(13,5))
plt.title("Ranks ")
ax=sns.barplot(y="country",x="rank",data=Rank)
for bars in ax.containers:
    ax.bar_label(bars)
    
    plt.xlabel("Country")
    plt.ylabel("Rank")
plt.show()

# %%
growth=df.nlargest(10,"growthRate")
plt.figure(figsize=(10,5))

sns.barplot(y="growthRate",x="country",data=growth)
# Out:
# <Axes: xlabel='country', ylabel='growthRate'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 224 entries, 0 to 226
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          224 non-null    object
#  1   rank             224 non-null    int64
#  2   area             224 non-null    int32
#  3   landAreaKm       224 non-null    float64
#  4   cca2             224 non-null    object
#  5   cca3             224 non-null    object
#  6   netChange        224 non-null    float64
#  7   growthRate       224 non-null    float64
#  8   worldPercentage  224 non-null    float64
#  9   density          224 non-null    float64
#  10  densityMi        224 non-null    float64
#  11  place            224 non-null    int64
#  12  pop1980          224 non-null    int64
#  13  pop2000          224 non-null    int64
#  14  pop2010          224 non-null    int64
#  15  pop2022          224 non-null    int64
#  16  pop2023          224 non-null    int64
# ...

# %%
Density=df.nlargest(10,"density")
plt.figure(figsize=(12,6))
sns.barplot(x="country",y="density",data=Density)
plt.show()

# %%
countries = ['India', 'China', 'United States', 'United Kingdom', 'Japan']

years = ['pop1980', 'pop2000', 'pop2010', 'pop2023','pop2030','pop2050']  

plt.figure(figsize=(10, 6)) 

for country in countries:
    country_data = df[df['country'] == country]
    plt.plot(years, country_data[years].values.reshape(-1),label=country)

plt.xlabel('Year')
plt.ylabel('Population')
plt.title('Population Trend for Selected Countries')
plt.legend()
plt.show()

# %% [markdown]
# **Conclusion:**

# %% [markdown]
# *1. Russia has largest Area*

# %% [markdown]
# *2. India is on Number 1 Ranking*

# %% [markdown]
# *3. Syria,Moldova,Niger has the highest growth rate*

# %% [markdown]
# *4. Macao,Monaco,Singapore has the large density*

# %% [markdown]
# *5. India and China are the two countries which has the largest population*

# %% [markdown]
# Thankyou!
